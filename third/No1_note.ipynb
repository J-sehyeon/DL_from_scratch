# %% [markdown]
# ## step01

# %%
from third.main import *

# %%
import numpy as np

# Variable 인스턴스 = x 생성
data = np.array(1.0)
x = Variable(data)
print(x.data)
# Out:
# 1.0

# %%
# 보충
x = np.array(1)
print(x.ndim)
y = np.array([1, 2, 3])
print(y.ndim)
z = np.array([[1, 2, 3],
              [4, 5, 6]])
print(z.ndim)
# Out:
# 0
# 1
# 2

# %% [markdown]
# ## step02

# %%
x = Variable(np.array(10))
f = Square()        # 변수 입력 x
y = f(x)            # 여기서 변수 입력  / 부모 클래스의 __call__ 메서드
print(type(y))
print(y.data)
# Out:
# <class 'No1.Variable'>
# 100
